# %% [markdown]
# # Part I-A

# %%
# importing libraries
import pandas as pd
import matplotlib as mp
from matplotlib import pyplot as plt
import seaborn as sns
import glob, os
from numpy import where as IF

# %%
# Reading value from csv file and creating a new data set 
State_wise_GDP = pd.read_csv('F:\\UPGRAD\\Assignment\\GDP Analysis\\PART I - A\\State_wise_GDP_at_current_price_on_yearly_basis.csv')

# %%
# check the information about how many non null values are present in data or data types of columsn etc using .info function
State_wise_GDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 36 columns):
# Items  Description           11 non-null object
# Duration                     11 non-null object
# Andhra Pradesh               11 non-null float64
# Arunachal Pradesh            9 non-null float64
# Assam                        9 non-null float64
# Bihar                        9 non-null float64
# Chhattisgarh                 11 non-null float64
# Goa                          9 non-null float64
# Gujarat                      9 non-null float64
# Haryana                      11 non-null float64
# Himachal Pradesh             7 non-null float64
# Jammu & Kashmir              9 non-null float64
# Jharkhand                    9 non-null float64
# Karnataka                    9 non-null float64
# Kerala                       9 non-null float64
# Madhya Pradesh               11 non-null float64
# Maharashtra                  7 non-null float64
# ...

# %%
# Check how many rows and columns are there in dataframe
State_wise_GDP.shape # 11 = Rows , 36 = columns
# Out:
# (11, 36)

# %%
State_wise_GDP.columns # Give you the List of columns in a dataframe
# Out:
# Index(['Items  Description', 'Duration', 'Andhra Pradesh ',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal1', 'Andaman & Nicobar Islands',
#        'Chandigarh', 'Delhi', 'Puducherry', 'All_India GDP'],
#       dtype='object')

# %%
State_wise_GDP.dtypes # Datatypes of columns
# Out:
# Items  Description            object
# Duration                      object
# Andhra Pradesh               float64
# Arunachal Pradesh            float64
# Assam                        float64
# Bihar                        float64
# Chhattisgarh                 float64
# Goa                          float64
# Gujarat                      float64
# Haryana                      float64
# Himachal Pradesh             float64
# Jammu & Kashmir              float64
# Jharkhand                    float64
# Karnataka                    float64
# Kerala                       float64
# Madhya Pradesh               float64
# Maharashtra                  float64
# Manipur                      float64
# Meghalaya                    float64
# Mizoram                      float64
# Nagaland                     float64
# Odisha                       float64
# Punjab                       float64
# Rajasthan                    float64
# Sikkim                       float64
# ...

# %%
# Describe function will provide you the info of numeric fields bout the min value, max value , mean , standard deviation and quantiles
State_wise_GDP.describe()
# Out:
#        Andhra Pradesh   Arunachal Pradesh          Assam          Bihar  \
# count        11.000000           9.000000       9.000000       9.000000
# mean     280986.561818        8201.516667  100018.167778  181565.673333
# std      282573.532407        8073.276061   97589.497456  178700.497677
# min           8.430000          12.070000       9.560000      10.590000
# 25%          14.025000          14.790000      13.190000      14.250000
# 50%      379402.000000       11063.000000  143175.000000  247144.000000
# 75%      495370.000000       14602.000000  177745.000000  317101.000000
# max      699307.000000       18784.000000  224234.000000  413503.000000
#
#         Chhattisgarh           Goa        Gujarat        Haryana  \
# count      11.000000      9.000000       9.000000      11.000000
# mean   120748.879091  22450.120000  448568.674444  228667.271818
# std    120928.480448  21443.429799  438025.627165  228195.895576
# ...

# %%
State_wise_GDP.count() # Will count non null Data  in dataframe
# Out:
# Items  Description           11
# Duration                     11
# Andhra Pradesh               11
# Arunachal Pradesh             9
# Assam                         9
# Bihar                         9
# Chhattisgarh                 11
# Goa                           9
# Gujarat                       9
# Haryana                      11
# Himachal Pradesh              7
# Jammu & Kashmir               9
# Jharkhand                     9
# Karnataka                     9
# Kerala                        9
# Madhya Pradesh               11
# Maharashtra                   7
# Manipur                       7
# Meghalaya                    11
# Mizoram                       7
# Nagaland                      7
# Odisha                       11
# Punjab                        7
# Rajasthan                     7
# Sikkim                        9
# Tamil Nadu                   11
# Telangana                    11
# Tripura                       7
# Uttar Pradesh                 9
# ...

# %%
#checks if any column contain any null values
State_wise_GDP.isna() # Will print all the NA Values in boolean form
# Out:
#     Items  Description  Duration  Andhra Pradesh   Arunachal Pradesh  Assam  \
# 0                False     False            False              False  False
# 1                False     False            False              False  False
# 2                False     False            False              False  False
# 3                False     False            False              False  False
# 4                False     False            False              False  False
# 5                False     False            False               True   True
# 6                False     False            False              False  False
# 7                False     False            False              False  False
# 8                False     False            False              False  False
# 9                False     False            False              False  False
# 10               False     False            False               True   True
#
# ...

# %%
State_wise_GDP.isna().sum() # will give the sum of all NA Values of Each Column
# Out:
# Items  Description            0
# Duration                      0
# Andhra Pradesh                0
# Arunachal Pradesh             2
# Assam                         2
# Bihar                         2
# Chhattisgarh                  0
# Goa                           2
# Gujarat                       2
# Haryana                       0
# Himachal Pradesh              4
# Jammu & Kashmir               2
# Jharkhand                     2
# Karnataka                     2
# Kerala                        2
# Madhya Pradesh                0
# Maharashtra                   4
# Manipur                       4
# Meghalaya                     0
# Mizoram                       4
# Nagaland                      4
# Odisha                        0
# Punjab                        4
# Rajasthan                     4
# Sikkim                        2
# Tamil Nadu                    0
# Telangana                     0
# Tripura                       4
# Uttar Pradesh                 2
# ...

# %%
State_wise_GDP.isna().sum() # will give the sum of all NA Values of Each Column
# Out:
# Items  Description            0
# Duration                      0
# Andhra Pradesh                0
# Arunachal Pradesh             2
# Assam                         2
# Bihar                         2
# Chhattisgarh                  0
# Goa                           2
# Gujarat                       2
# Haryana                       0
# Himachal Pradesh              4
# Jammu & Kashmir               2
# Jharkhand                     2
# Karnataka                     2
# Kerala                        2
# Madhya Pradesh                0
# Maharashtra                   4
# Manipur                       4
# Meghalaya                     0
# Mizoram                       4
# Nagaland                      4
# Odisha                        0
# Punjab                        4
# Rajasthan                     4
# Sikkim                        2
# Tamil Nadu                    0
# Telangana                     0
# Tripura                       4
# Uttar Pradesh                 2
# ...

# %%
State_wise_GDP.isnull().sum() # will give the sum of all Null Values of Each Column
# Out:
# Items  Description            0
# Duration                      0
# Andhra Pradesh                0
# Arunachal Pradesh             2
# Assam                         2
# Bihar                         2
# Chhattisgarh                  0
# Goa                           2
# Gujarat                       2
# Haryana                       0
# Himachal Pradesh              4
# Jammu & Kashmir               2
# Jharkhand                     2
# Karnataka                     2
# Kerala                        2
# Madhya Pradesh                0
# Maharashtra                   4
# Manipur                       4
# Meghalaya                     0
# Mizoram                       4
# Nagaland                      4
# Odisha                        0
# Punjab                        4
# Rajasthan                     4
# Sikkim                        2
# Tamil Nadu                    0
# Telangana                     0
# Tripura                       4
# Uttar Pradesh                 2
# ...

# %% [markdown]
# ### Remove the rows: '(% Growth over the previous year)' and 'GSDP - CURRENT PRICES (` in Crore)' for the year 2016-17 :

# %%
# Dropping the rows with duration = 2016-17 
State_wise_GDP.drop([5,10],inplace=True)
State_wise_GDP.dropna()
State_wise_GDP
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
#Here the index is not proper so using .reset_index(), drop = true will reset in the original index itself
State_wise_GDP.reset_index(drop=True)
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5       (% Growth over previous year)  2012-13             8.43
# 6       (% Growth over previous year)  2013-14            12.85
# 7       (% Growth over previous year)  2014-15            13.40
# 8       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %% [markdown]
# ### Calculate the average growth of states for the duration 2013-14, 2014-15 and 2015-16 by taking the mean of the row '(% Growth over previous year)' :

# %%
#Filtering the data where "Item Description" = '(% Growth over previous year)' and "Duration" = 2012-13 
State_Wise_Mean = State_wise_GDP[(State_wise_GDP["Items  Description"] == '(% Growth over previous year)') & (State_wise_GDP.Duration != '2012-13')]
State_Wise_Mean.reset_index(drop = True)
# Out:
#               Items  Description Duration  Andhra Pradesh   Arunachal Pradesh  \
# 0  (% Growth over previous year)  2013-14            12.85              16.38
# 1  (% Growth over previous year)  2014-15            13.40              14.79
# 2  (% Growth over previous year)  2015-16            15.85              12.07
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana  ...  Telangana  \
# 0  13.31  12.30         16.44  -5.77    11.47    15.45  ...      12.63
# 1  11.45  17.92         13.69  13.12    10.82     9.18  ...      13.05
# 2  13.19  10.59         10.98  10.75    11.09    10.91  ...      12.61
#
#    Tripura  Uttar Pradesh  Uttarakhand  West Bengal1  \
# 0    18.14          14.73        13.64           NaN
# 1    15.92          10.51         8.12           NaN
# 2      NaN          10.58        13.65           NaN
#
#    Andaman & Nicobar Islands  Chandigarh  Delhi  Puducherry  All_India GDP
# ...

# %%
# will give you mean statewise
Mean_Value = State_wise_GDP.groupby(State_Wise_Mean["Items  Description"]).mean() 
# reset index 
Mean_Value.reset_index() 
Mean_Value=Mean_Value.T
Mean_Value.dropna(inplace=True)

# %%
# renaming column names
Mean_Value = Mean_Value.rename(columns={"Items  Description" : "State","(% Growth over previous year)" : "Mean"})

# %% [markdown]
# ### Compare the calculated values and plot them for the states. :

# %%
#  Adjusting the figsize to draw the graph. Here subplot(1,1) mean the canvas required to draw the graph
# figsize=(16,5) is for the graph size i.e 16 rows and 5 column sized graph will be fit on the suplot(1,1)
fig,ax=plt.subplots(1,1,figsize=(16,5)) 
# Drawing Bar graph which has blue colored bars in it
Mean_Value.plot(kind="bar",ax=ax,color='blue')
# xticks helps in rotating the Axis points.
plt.xticks(rotation=90)
# Title to be seen on X-Axis is passed in xlabel.
plt.xlabel('States') 
# Title to be seen on Y-Axis is passed in ylabel.
plt.ylabel('Mean Value')
plt.show()

# %% [markdown]
# ### Which states have been growing consistently fast, and which ones have been struggling?

# %%
fig,ax=plt.subplots(1,1,figsize=(16,5)) 
# Drawing Bar graph which has green colored bars in it
Mean_Value.sort_values(by="Mean").plot(kind="bar",ax=ax,color='green')
# xticks helps in rotating the Axis points.
plt.xticks(rotation=90)
# Title to be seen on X-Axis is passed in xlabel.
plt.xlabel('States') 
# Title to be seen on Y-Axis is passed in ylabel.
plt.ylabel('Mean Value')
plt.show() # To display the graph

# %% [markdown]
# ###  <span style="color:blue">SOLUTION : Here the State Mizoram is consistently fast and Goa is struggling more than other states.All other states like Puducherry, Delhi,MadhyaPradesh and etc are doing well not very fast not very slow       </span>

# %% [markdown]
# ### What has been the average growth rate of your home state, and how does it compare to the national average over this duration?

# %% [markdown]
# ### <span style="color:blue"> SOLUTION : My home town is Maharashtra and is doing well as it's average is same as the averge of All India GDP.As by seeing the graph we can identify that the eastern states are consistently fast compare to other states
# </span>

# %% [markdown]
# ### Plot the total GDP of the states for the year 2015-16 :

# %%
# Filtering data where "Item Description" = 'GSDP - CURRENT PRICES (` in Crore)' and "Duration" = 2015-16
Graph2 = State_wise_GDP[(State_wise_GDP["Items  Description"] == 'GSDP - CURRENT PRICES (` in Crore)') & (State_wise_GDP.Duration == '2015-16')]
Graph2.reset_index()
# Out:
#    index                  Items  Description Duration  Andhra Pradesh   \
# 0      4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 0            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#    ...  Telangana  Tripura  Uttar Pradesh  Uttarakhand  West Bengal1  \
# 0  ...   575631.0      NaN      1153795.0     184091.0           NaN
#
#    Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry  All_India GDP
# 0                        NaN     30304.0  551963.0     26533.0     13675331.0
#
# [1 rows x 37 columns]

# %%
# Droping 2 columns i.e "Item description" & "Duration"
Graph2.drop(["Items  Description","Duration"], axis = 'columns', inplace=True)
Graph2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#    Andhra Pradesh   Arunachal Pradesh     Assam     Bihar  Chhattisgarh  \
# 4         609934.0            18784.0  224234.0  413503.0      260776.0
#
#        Goa   Gujarat   Haryana  Himachal Pradesh  Jammu & Kashmir  ...  \
# 4  45002.0  994316.0  485184.0               NaN         118387.0  ...
#
#    Telangana  Tripura  Uttar Pradesh  Uttarakhand  West Bengal1  \
# 4   575631.0      NaN      1153795.0     184091.0           NaN
#
#    Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry  All_India GDP
# 4                        NaN     30304.0  551963.0     26533.0     13675331.0
#
# [1 rows x 34 columns]

# %%
Graph2 = Graph2.T #Transpose

# %%
# Droping Column All India GDP
Graph2.drop(["All_India GDP"],inplace = True)

# %%
Graph2.dropna(inplace=True) #Drop NA Values 
Graph2
# Out:
#                            4
# Andhra Pradesh      609934.0
# Arunachal Pradesh    18784.0
# Assam               224234.0
# Bihar               413503.0
# Chhattisgarh        260776.0
# Goa                  45002.0
# Gujarat             994316.0
# Haryana             485184.0
# Jammu & Kashmir     118387.0
# Jharkhand           241955.0
# Karnataka          1027068.0
# Kerala              588337.0
# Madhya Pradesh      543975.0
# Meghalaya            26745.0
# Odisha              341887.0
# Sikkim               16637.0
# Tamil Nadu         1212668.0
# Telangana           575631.0
# Uttar Pradesh      1153795.0
# Uttarakhand         184091.0
# Chandigarh           30304.0
# Delhi               551963.0
# Puducherry           26533.0

# %%
Graph2=Graph2.sort_values(by=[4]) #Sort values

# %%
# Plotting graoh to identify the top5 and bottom5 states
fig,ax=plt.subplots(1,1,figsize=(16,5)) 
Graph2.sort_values([4]).plot(kind="bar",ax=ax,color='purple')
plt.xlabel('States') 
plt.ylabel('GDP')
plt.show()

# %%
# Calculating top 5 states with maximum mean values
Top5 = Graph2[0:5] # or can use .head(n=5)
# Top5.reset_index()
# Graph2.head(5)
Top5
# Out:
#                          4
# Sikkim             16637.0
# Arunachal Pradesh  18784.0
# Puducherry         26533.0
# Meghalaya          26745.0
# Chandigarh         30304.0

# %%
# Calcultion Bottom 5 States with minimum mean values
Bottom5 = Graph2.tail()
Bottom5.reset_index()
# Out:
#              index          4
# 0  Andhra Pradesh    609934.0
# 1          Gujarat   994316.0
# 2        Karnataka  1027068.0
# 3    Uttar Pradesh  1153795.0
# 4       Tamil Nadu  1212668.0

# %%
# Merging the two data frma top5 and bottom5 and creating a single df with name Merge
Merge = Top5.append(Bottom5) #merging two dataframes and combining it in one
Merge
# Out:
#                            4
# Sikkim               16637.0
# Arunachal Pradesh    18784.0
# Puducherry           26533.0
# Meghalaya            26745.0
# Chandigarh           30304.0
# Andhra Pradesh      609934.0
# Gujarat             994316.0
# Karnataka          1027068.0
# Uttar Pradesh      1153795.0
# Tamil Nadu         1212668.0

# %% [markdown]
# ### Identify the top 5 and the bottom 5 states based on total GDP.

# %%
# Plotting graoh to identify the top5 and bottom5 states
fig,ax=plt.subplots(1,1,figsize=(16,5)) 
Merge.sort_values([4]).plot(kind="bar",ax=ax,color='red')
plt.xlabel('States') 
plt.ylabel('GDP')
plt.show()

# %% [markdown]
# ### <span style="color:blue"> Solution : Here we can notice that the state Uttar Prdesh have the maximum mean value compared to any other states.Like wise Arunachal Pradesh have minimum mean values compared to other statesHe graph here is in sorted order which is in high to low range </span>

# %% [markdown]
# # PART I-B

# %%
# Path where all the files are stored
path = r'F:\UPGRAD\Assignment\GDP Analysis\PART I -B' 
path
# Out:
# 'F:\\UPGRAD\\Assignment\\GDP Analysis\\PART I -B'

# %%
# Reading all the paths
all_files = glob.glob(path + "/*.csv")
all_files
# Out:
# ['F:\\UPGRAD\\Assignment\\GDP Analysis\\PART I -B\\NAD-Andaman_Nicobar_Islands-GSVA_cur_2014-15.csv',
#  'F:\\UPGRAD\\Assignment\\GDP Analysis\\PART I -B\\NAD-Andhra_Pradesh-GSVA_cur_2016-17.csv',
#  'F:\\UPGRAD\\Assignment\\GDP Analysis\\PART I -B\\NAD-Arunachal_Pradesh-GSVA_cur_2015-16.csv',
#  'F:\\UPGRAD\\Assignment\\GDP Analysis\\PART I -B\\NAD-Assam-GSVA_cur_2015-16.csv',
#  'F:\\UPGRAD\\Assignment\\GDP Analysis\\PART I -B\\NAD-Bihar-GSVA_cur_2015-16.csv',
#  'F:\\UPGRAD\\Assignment\\GDP Analysis\\PART I -B\\NAD-Chandigarh-GSVA_cur_2015-16.csv',
#  'F:\\UPGRAD\\Assignment\\GDP Analysis\\PART I -B\\NAD-Chhattisgarh-GSVA_cur_2016-17.csv',
#  'F:\\UPGRAD\\Assignment\\GDP Analysis\\PART I -B\\NAD-Delhi-GSVA_cur_2016-17.csv',
#  'F:\\UPGRAD\\Assignment\\GDP Analysis\\PART I -B\\NAD-Goa-GSVA_cur_2015-16.csv',
#  'F:\\UPGRAD\\Assignment\\GDP Analysis\\PART I -B\\NAD-Gujarat-GSVA_cur_2015-16.csv',
#  'F:\\UPGRAD\\Assignment\\GDP Analysis\\PART I -B\\NAD-Haryana-GSVA_cur_2016-17.csv',
# ...

# %%
# Empty list to add all the dataframes
li = []

# %%
# Loop to read each file with the path given in the filename variable.
for filename in all_files:
    # Reading each file as a pandas dataframe
    df = pd.read_csv(filename, index_col=None, header=0,encoding='unicode_escape')
    # Selecting only required columns
    df = df[['Item','2014-15']]
    # Transpose the data
    df = df.T
    # Taking the header row
    new_header = df.iloc[0] #grab the first row for the header
    df = df[1:] #take the data less the header row
    # Assign the new header
    df.columns = new_header 
    # Add the section name from the filename
    df['Section'] = filename.split('\\')[-1].split('.')[0].split('-')[1]
    # Append the final DF to the list
    li.append(df)

# %%
# Creating a final DF by joining all the df's in the list li
frame = pd.concat(li, axis=0, ignore_index=True,sort=True)

# %%
frame1 = frame

# %% [markdown]
# ### Filter out the union territories (Delhi, Chandigarh, Andaman and Nicobar Islands, etc.)

# %%
frame.drop([5,7,0,22],inplace=True)

# %% [markdown]
# ### Plot the GDP per capita for all the states

# %%
# Plotting the garph to see the Per Capita  Statewise
fig,ax=plt.subplots(1,1,figsize=(13,8)) 
frame.plot(kind="barh",x= "Section",y = "Per Capita GSDP (Rs.)",ax=ax,color='blue')
# plt.xticks(rotation=90)
plt.xlabel('Per Capita') 
plt.ylabel('States')
plt.show()

# %% [markdown]
# ### Identify the top 5 and the bottom 5 states based on the GDP per capita.

# %%
# Plotting Graph is srted order i.e from high to low
fig,ax=plt.subplots(1,1,figsize=(13,8)) 
frame.sort_values(by="Per Capita GSDP (Rs.)").plot(kind="barh",x= "Section",y = "Per Capita GSDP (Rs.)",ax=ax,color='red')
# plt.xticks(rotation=90)
plt.xlabel('Per Capita') 
plt.ylabel('States')
plt.show()

# %%
Df = frame.sort_values(by = "Per Capita GSDP (Rs.)",ascending=False) # Sorting Frame as per Per Capita GSDP (Rs.) in descending Order

# %%
Df.reset_index(drop=True,inplace=True)

# %%
Top5 = Df.head(n=5) # Creating Top5 states 
Top5
# Out:
#   Agriculture, forestry and fishing Air transport  \
# 0                            308507         46359
# 1                            137447             0
# 2                       8.01524e+06           NaN
# 3                           5930617        125029
# 4                       1.60142e+06          3889
#
#   Communication & services related to broadcasting Construction        Crops  \
# 0                                            44028       165819       140421
# 1                                            12064        82058       114976
# 2                                           479658  3.70257e+06  4.63673e+06
# 3                                           884767      7314003      3070386
# 4                                           733778  1.34273e+06       866146
#
#   Electricity, gas, water supply & other utility services Financial services  \
# 0                                             204110                  233618
# ...

# %%
Bottom5 = Df.tail(n=5)  # Identifying bottom5 states
Bottom5
# Out:
#    Agriculture, forestry and fishing Air transport  \
# 22                           3211065          6716
# 23                           3855548         26223
# 24                            383140          6288
# 25                          25097754         36582
# 26                           7951890         13599
#
#    Communication & services related to broadcasting Construction     Crops  \
# 22                                           323214      1789834   2094466
# 23                                           357619      1733568   2890544
# 24                                            42017       143182    226583
# 25                                          1914737     11256450  16215212
# 26                                           919427      3449763   4688237
#
#    Electricity, gas, water supply & other utility services Financial services  \
# 22                                             337489                  551441
# ...

# %%
TB = Top5.append(Bottom5) # Concating to dataframe and forming 1 single DF
TB
# Out:
#    Agriculture, forestry and fishing Air transport  \
# 0                             308507         46359
# 1                             137447             0
# 2                        8.01524e+06           NaN
# 3                            5930617        125029
# 4                        1.60142e+06          3889
# 22                           3211065          6716
# 23                           3855548         26223
# 24                            383140          6288
# 25                          25097754         36582
# 26                           7951890         13599
#
#    Communication & services related to broadcasting Construction        Crops  \
# 0                                             44028       165819       140421
# 1                                             12064        82058       114976
# 2                                            479658  3.70257e+06  4.63673e+06
# 3                                            884767      7314003      3070386
# ...

# %%
# Plotting Graph for vlues of PEr Capita GSP statewise
fig,ax=plt.subplots(1,1,figsize=(13,8)) 
TB.sort_values(by="Per Capita GSDP (Rs.)").plot(kind="barh",x= "Section",y = "Per Capita GSDP (Rs.)",ax=ax,color='black')
# plt.xticks(rotation=90)
plt.xlabel('Per Capita') 
plt.ylabel('States')
plt.show()

# %% [markdown]
# ### Find the ratio of the highest per capita GDP to the lowest per capita GDP.

# %%
ratio = Df["Per Capita GSDP (Rs.)"].max()/Df["Per Capita GSDP (Rs.)"].min() 
ratio
# Out:
# 8.004741709371503

# %% [markdown]
# ### Plot the percentage contribution of the primary, secondary and tertiary sectors as a percentage of the total GDP for all the states

# %%
Df.head()
# Out:
#   Agriculture, forestry and fishing Air transport  \
# 0                            308507         46359
# 1                            137447             0
# 2                       8.01524e+06           NaN
# 3                           5930617        125029
# 4                       1.60142e+06          3889
#
#   Communication & services related to broadcasting Construction        Crops  \
# 0                                            44028       165819       140421
# 1                                            12064        82058       114976
# 2                                           479658  3.70257e+06  4.63673e+06
# 3                                           884767      7314003      3070386
# 4                                           733778  1.34273e+06       866146
#
#   Electricity, gas, water supply & other utility services Financial services  \
# 0                                             204110                  233618
# ...

# %%
Data = Df.groupby("Section")["Primary","Secondary","Tertiary","Gross State Domestic Product"].sum()
Data
# Out:
#                       Primary   Secondary    Tertiary  \
# Section
# Andhra_Pradesh     16303716.0  10488884.0  22032942.0
# Arunachal_Pradesh    716959.0    287489.0    631844.0
# Assam               5326697.0   4033091.0   9307109.0
# Bihar               8019997.0   5984896.0  22179969.0
# Chhattisgarh        6400817.0   8238886.0   7588778.0
# Goa                  312129.0   1547536.0   1738217.0
# Gujarat            15887187.0  33023538.0  30220377.0
# Haryana             8040424.0  12561411.0  19226568.0
# Himachal_Pradesh    1548366.0   4119162.0   4133326.0
# Jharkhand           5248354.0   6241471.0   8133341.0
# Karnataka          12066304.0  20484404.0  50490630.0
# Kerala              6489442.0  12070040.0  29673778.0
# Madhya_Pradesh     17854020.0  10044889.0  18117360.0
# Maharashtra        21758383.0  47445207.0  88631076.0
# Manipur              383140.0    220173.0   1177334.0
# Meghalaya            451050.0    637942.0   1200655.0
# ...

# %%
# Deriving 3 columns Primary%,Secondary% & Tertiry %
Data["Primary %"] = Data["Primary"]/Data["Gross State Domestic Product"]*100
Data["Secondary %"] = Data["Secondary"]/Data["Gross State Domestic Product"]*100
Data["Tertiary %"] = Data["Tertiary"]/Data["Gross State Domestic Product"]*100
Data
# Out:
#                       Primary   Secondary    Tertiary  \
# Section
# Andhra_Pradesh     16303716.0  10488884.0  22032942.0
# Arunachal_Pradesh    716959.0    287489.0    631844.0
# Assam               5326697.0   4033091.0   9307109.0
# Bihar               8019997.0   5984896.0  22179969.0
# Chhattisgarh        6400817.0   8238886.0   7588778.0
# Goa                  312129.0   1547536.0   1738217.0
# Gujarat            15887187.0  33023538.0  30220377.0
# Haryana             8040424.0  12561411.0  19226568.0
# Himachal_Pradesh    1548366.0   4119162.0   4133326.0
# Jharkhand           5248354.0   6241471.0   8133341.0
# Karnataka          12066304.0  20484404.0  50490630.0
# Kerala              6489442.0  12070040.0  29673778.0
# Madhya_Pradesh     17854020.0  10044889.0  18117360.0
# Maharashtra        21758383.0  47445207.0  88631076.0
# Manipur              383140.0    220173.0   1177334.0
# Meghalaya            451050.0    637942.0   1200655.0
# ...

# %%
#Plotting Graph to show the %Conttribution of each sector
colors = ["orange", "green","brown"]
fig,ax=plt.subplots(1,1,figsize=(15,8)) 
Data.plot(kind="bar",y = ["Primary %","Secondary %","Tertiary %"],ax=ax,stacked = True,color=colors)
# plt.xticks(rotation=90)
plt.xlabel('States') 
plt.ylabel('% Contribution')
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# ### Categorise the states into four groups based on the GDP per capita (C1, C2, C3, C4, where C1 would have the highest per capita GDP and C4, the lowest). The quantile values are (0.20,0.5, 0.85, 1), i.e., the states lying between the 85th and the 100th percentile are in C1; those between the 50th and the 85th percentiles are in C2, and so on.

# %%
Df.describe()
# Out:
#         Agriculture, forestry and fishing  Air transport  \
# count                                27.0           24.0
# unique                               27.0           23.0
# top                            16235647.0            0.0
# freq                                  1.0            2.0
#
#         Communication & services related to broadcasting  Construction  \
# count                                               27.0          27.0
# unique                                              27.0          27.0
# top                                             294552.0     3449763.0
# freq                                                 1.0           1.0
#
#            Crops  Electricity, gas, water supply & other utility services  \
# count       27.0                                               27.0
# unique      27.0                                               27.0
# top     223330.0                                          3409983.0
# ...

# %%
Data = Df["Per Capita GSDP (Rs.)"].quantile([0.20,0.5, 0.85, 1]) # Clculating Quantile Vlue of Dataframe Df

# %%
Data[0.85]
# Data
# Out:
# 153246.19999999998

# %%
#Deriring new column Category in Df Dataframe 
Df['Category']=IF(Df['Per Capita GSDP (Rs.)']<=Data[0.20],'C1',
                IF((Df['Per Capita GSDP (Rs.)']>Data[0.20]) & (Df['Per Capita GSDP (Rs.)']<=Data[0.5]),'C2',
                IF((Df['Per Capita GSDP (Rs.)']>Data[0.50]) & (Df['Per Capita GSDP (Rs.)']<=Data[0.85]),'C3',
                IF((Df['Per Capita GSDP (Rs.)']>Data[0.85]),'C4',''))))

# %%
# Creating a new list of subsectors 
Sub_Sector = list(Df.columns)
Sub_Sector.remove("Section") # Remove unwanted Columns from this list
Sub_Sector.remove("TOTAL GSVA at basic prices")
Sub_Sector.remove("Category")
Sub_Sector.remove("Population ('00)")
Sub_Sector.remove("Tertiary")
Sub_Sector.remove("Secondary")
Sub_Sector.remove("Primary")
Sub_Sector.remove("Communication & services related to broadcasting")
Sub_Sector.remove("Construction")
Sub_Sector.remove("Crops")
Sub_Sector.remove("Livestock")
Sub_Sector.remove("Forestry and logging")
Sub_Sector.remove("Fishing and aquaculture")
Sub_Sector.remove("Trade & repair services")
Sub_Sector.remove("Hotels & restaurants")
Sub_Sector.remove("Railways")
Sub_Sector.remove("Road transport*")
Sub_Sector.remove("Road transport**")
Sub_Sector.remove("Air transport")
Sub_Sector.remove("Services incidental to transport*")
Sub_Sector.remove("Storage")
Sub_Sector.remove("Water transport")
Sub_Sector.remove("Trade & repair services*")

Sub_Sector
# Out:
# ['Agriculture, forestry and fishing',
#  'Electricity, gas, water supply & other utility services',
#  'Financial services',
#  'Gross State Domestic Product',
#  'Manufacturing',
#  'Mining and quarrying',
#  'Other services',
#  'Per Capita GSDP (Rs.)',
#  'Public administration',
#  'Real estate, ownership of dwelling & professional services',
#  'Road transport',
#  'Services incidental to transport',
#  'Subsidies on products',
#  'Taxes on Products',
#  'Trade, repair, hotels and restaurants',
#  'Transport, storage, communication & services related to broadcasting']

# %%
C1 = pd.DataFrame(Df.groupby("Category")[Sub_Sector].sum()).loc["C1"].reset_index()
C2 = pd.DataFrame(Df.groupby("Category")[Sub_Sector].sum()).loc["C2"].reset_index()
C3 = pd.DataFrame(Df.groupby("Category")[Sub_Sector].sum()).loc["C3"].reset_index()
C4 = pd.DataFrame(Df.groupby("Category")[Sub_Sector].sum()).loc["C4"].reset_index()
C1.sort_values(by ='C1',inplace = True,ascending=False)
C1.reset_index(drop = True,inplace = True)
C2.sort_values(by ='C2',inplace = True,ascending=False)
C2.reset_index(drop = True,inplace = True)
C3.sort_values(by ='C3',inplace = True,ascending=False)
C3.reset_index(drop = True,inplace = True)
C4.sort_values(by ='C4',inplace = True,ascending=False)
C4.reset_index(drop = True,inplace = True)

# %%
gdpval1=C1.C1[0]
gdpval2=C2.C2[0]
gdpval3=C3.C3[0]
gdpval4=C4.C4[0]

# %%
C1['pc_contri']= round((C1.C1[1:]/gdpval1)*100,2)
C2['pc_contri']= round((C2.C2[1:]/gdpval2)*100,2)
C3['pc_contri']= round((C3.C3[1:]/gdpval3)*100,2)
C4['pc_contri']= round((C4.C4[1:]/gdpval4)*100,2)

# %%
sum_of_c=pd.concat([C1,C2,C3,C4],axis=0,sort=True)

# %%
sum_of_c=sum_of_c.groupby(['index']).sum()
sum_of_c=sum_of_c.dropna()

# %%
sum_of_c['pc_contri']= round(sum_of_c['pc_contri'],2)
sum_of_c=sum_of_c.sort_values(['pc_contri'],ascending=False).reset_index()

# %%
sum_of_c=sum_of_c[0:15]

# %%
fig,ax=plt.subplots(1,1,figsize=(18,6))
sum_of_c.plot(kind='bar',x='index',y='pc_contri',ax=ax)  
plt.ylim(0,100)
plt.xlabel('Sectors Contributing To GDP')
plt.ylabel('Percentage Contribution To GDP')
plt.show()

# %% [markdown]
# # PART - II

# %%
Drop_Out_Detail = pd.read_csv("F:\\UPGRAD\\Assignment\\GDP Analysis\\PART II\\rs_session243_au570_1.1.csv")
Drop_Out_Detail
# Out:
#       Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0           1              A & N Islands                 0.68
# 1           2             Andhra Pradesh                 3.18
# 2           3          Arunachal Pradesh                15.16
# 3           4                      Assam                 6.24
# 4           5                      Bihar                  NaN
# 5           6                 Chandigarh                  NaN
# 6           7                Chhatisgarh                 4.14
# 7           8       Dadra & Nagar Haveli                  NaN
# 8           9                Daman & Diu                  NaN
# 9          10                      Delhi                  NaN
# 10         11                        Goa                  NaN
# 11         12                    Gujarat                 0.74
# 12         13                    Haryana                 1.29
# 13         14           Himachal Pradesh                 0.45
# ...

# %%
Drop_Out_Detail1 = Drop_Out_Detail[['Level of Education - State','Primary - 2014-2015','Upper Primary - 2014-2015','Secondary - 2014-2015']]
Drop_Out_Detail1
# Out:
#    Level of Education - State  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0               A & N Islands                 1.21                       1.69
# 1              Andhra Pradesh                 4.35                       5.20
# 2           Arunachal Pradesh                10.89                       6.71
# 3                       Assam                 7.44                      10.51
# 4                       Bihar                 2.09                       4.08
# 5                  Chandigarh                  NaN                       0.44
# 6                 Chhatisgarh                 1.42                       5.85
# 7        Dadra & Nagar Haveli                 1.57                       4.02
# 8                 Daman & Diu                 0.85                       3.11
# 9                       Delhi                  NaN                       0.76
# 10                        Goa                 0.20                       0.07
# ...

# %%
# Filtering out the union territory states from data frame
Drop_Out_Detail1=Drop_Out_Detail1.drop([0,5,7,8,9,18,26,36])
Drop_Out_Detail1.reset_index(drop=True,inplace = True)
Drop_Out_Detail1
# Out:
#    Level of Education - State  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0              Andhra Pradesh                 4.35                       5.20
# 1           Arunachal Pradesh                10.89                       6.71
# 2                       Assam                 7.44                      10.51
# 3                       Bihar                 2.09                       4.08
# 4                 Chhatisgarh                 1.42                       5.85
# 5                         Goa                 0.20                       0.07
# 6                     Gujarat                 0.76                       6.41
# 7                     Haryana                 0.41                       5.81
# 8            Himachal Pradesh                 0.46                       0.87
# 9           Jammu and Kashmir                 5.46                       5.44
# 10                  Jharkhand                 6.41                       8.99
# ...

# %%
Drop_Out_Detail1.rename(columns={'Level of Education - State':'States'},inplace=True)

# %%
#Renming the values in Drop Out Df to match it with the Aove Df Datafrme
Drop_Out_Detail1=Drop_Out_Detail1.replace(to_replace=['Andhra Pradesh','Arunachal Pradesh','Chhatisgarh','Himachal Pradesh','Madhya Pradesh','Tamil Nadu','Uttar Pradesh','Uttrakhand',],value=['Andhra_Pradesh','Arunachal_Pradesh','Chhattisgarh','Himachal_Pradesh','Madhya_Pradesh','Tamil_Nadu','Uttar_Pradesh','Uttarakhand'])

# %%
Drop_Out_Detail1
# Out:
#                States  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0      Andhra_Pradesh                 4.35                       5.20
# 1   Arunachal_Pradesh                10.89                       6.71
# 2               Assam                 7.44                      10.51
# 3               Bihar                 2.09                       4.08
# 4        Chhattisgarh                 1.42                       5.85
# 5                 Goa                 0.20                       0.07
# 6             Gujarat                 0.76                       6.41
# 7             Haryana                 0.41                       5.81
# 8    Himachal_Pradesh                 0.46                       0.87
# 9   Jammu and Kashmir                 5.46                       5.44
# 10          Jharkhand                 6.41                       8.99
# 11          Karnataka                 2.32                       3.85
# ...

# %%
Drop_Out_3 = Drop_Out_Detail1.merge(Df,right_on= "Section",left_on= "States",how="inner")

# %%
Drop_Out_3
# Out:
#                States  Primary - 2014-2015  Upper Primary - 2014-2015  \
# 0      Andhra_Pradesh                 4.35                       5.20
# 1   Arunachal_Pradesh                10.89                       6.71
# 2               Assam                 7.44                      10.51
# 3               Bihar                 2.09                       4.08
# 4        Chhattisgarh                 1.42                       5.85
# 5                 Goa                 0.20                       0.07
# 6             Gujarat                 0.76                       6.41
# 7             Haryana                 0.41                       5.81
# 8    Himachal_Pradesh                 0.46                       0.87
# 9           Jharkhand                 6.41                       8.99
# 10          Karnataka                 2.32                       3.85
# 11             Kerala                  NaN                        NaN
# ...

# %%
# Plotting the scatter plot to explain the impactof sector GSDP.
fig,ax=plt.subplots(ncols=3,figsize=(18,6))
sns.set_style("whitegrid")
cmap = sns.cubehelix_palette(dark=.9, light=.8, as_cmap=True)
sns.scatterplot(data=Drop_Out_3,x='Gross State Domestic Product',y='Primary - 2014-2015',ax=ax[0])
sns.scatterplot(data=Drop_Out_3,x='Gross State Domestic Product',y='Upper Primary - 2014-2015',ax=ax[1])
sns.scatterplot(data=Drop_Out_3,x='Gross State Domestic Product',y='Secondary - 2014-2015',ax=ax[2])
plt.show()
